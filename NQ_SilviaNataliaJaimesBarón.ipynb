# %% [markdown]
# #Laboratorio de mecánica-Ecuaciones empíricas

# %% [markdown]
# ##Resumen
#
# En todo experimento se obtiene un conjunto de valores correspondientes a dos variables, una dependiente de la otra. En el caso de este laboratorio se tiene en cuenta que el estudio de la relación existente entre la longitud de la cuerda y el número de oscilación tiene lugar para aplicar dicha teoría. Esta dependencia entre variables se expresa mediante una ecuación empírica. Esta la obtenemos a través de un gráfico de un conjunto de valores experimentales de dichas dos variables.

# %% [markdown]
# ##Introducción
#
# Las ecuaciones empíricas son aquellas basadas en la experimentación y observación de procesos de los cuales se desconocen algunos fenómenos involucrados en estos. En el presente informe de laboratorio se tratará la temática de las ecuaciones empíricas, para deducir la correcta ecuación empírica es necesario obtener un buen gráfico de nuestros datos experimentales; también para establecer la relación del periodo de oscilación con relación a su dimensión y su masa. Para ahondar más en el tema se investiga el comportamiento de un anillo oscilante de diferentes tamaños y como su dimensión puede variar su periodo de oscilación.

# %% [markdown]
# ##DESARROLLO EXPERIMENTAL
# Para el desarrollo de la practica lo primero que se desarrolló fue la elección de uno de los anillos
# para posteriormente hacer uso de la balanza y hallar el peso del anillo, a su vez se usó una tabla
# que sirviera de apoyo al anillo para así efectuar la medición.
#
# ![Imagen1.png](data:image/png;base64,...)

# %% [markdown]
# Siguiendo con la recolección de información se mide el diámetro interno y externo del anillo
#
# ![Imagen2.png](data:image/png;base64,...)

# %% [markdown]
# Se hace el montaje el sistema, donde se hace uso de un soporte metálico, base de hierro en la que
# se ajusta una varilla de un metro de longitud en la que con ayuda de nueces de sujeción se inserta
# otra varilla en la cual se insertará el anillo con una varilla corta que será la que pasará por el
# sensor infrarrojo tipo horquilla para que detecte el movimiento y con ayuda de la interfase del
# módulo CASSY LAB, calcule el periodo de oscilación del anillo.
#
# ![Imagen3.png](data:image/png;base64,...)

# %% [markdown]
# Después de la recolección de datos se organizaron en una tabla y a su vez se agregaron datos
# suministrados por nuestros compañeros sobre sus respectivos anillos
#
# ![Imagen4.png](data:image/png;base64,...)

# %% [markdown]
# ##RESULTADOS Y DISCUSIÓN
# ###ANÁLISIS DE DATOS
# 1. Transforme las mediciones tomadas al sistema internacional de unidades, longitud en
# metros, masa en kilogramos, y tiempo en segundos.

# %%
##Recolectamos el diametro en centímetros con ayuda de un metro, la masa fue recolectada en gramos y el tiempo ya estaba en segundos
##Así que vamos a hacer esas dos conversiones

B=float(input("Ingresa el valor que quieres convertir de centímetros a metros"))
t=B/100

C=float(input("Ingresa el valor que quieres convertir de gramos a kilogramos"))
x=C/100

print("El primer valor ingresado es",t, "metros" )
print("El segundo valor ingresado es",x, "gramos")
# Out:
# Ingresa el valor que quieres convertir de centimetros a metros1000
# Ingresa el valor que quieres convertir de gramos a kilogramos4000
# El primer valor ingresado es 10.0 metros
# El segundo valor ingresado es 40.0 gramos

# %%
##¡Hagamos las cosas más fáciles! 
##¡Usemos un programa para hallar el promedio de los diámetros!

print("En el laboratorio recolectamos 3 medidas para el diámetro interno y el diámetro externo \n con este programa hallaremos el promedio de los dos y el diametro medio.")
a=float(input("Por favor ingrese el primer valor el diámetro interno"))
b=float(input("Por favor ingrese el segundo valor el diámetro interno"))
c=float(input("Por favor ingrese el tercer valor el diámetro interno"))

d=float(input("Ahora, por favor ingrese el primer valor el diámetro externo"))
e=float(input("Por favor ingrese el segundo valor el diámetro externo"))
f=float(input("Por favor ingrese el tercer valor el diámetro externo"))

x= (a+b+c)/3
y= (d+e+f)/3
z= (x+y)/2


print("El promedio del diámetro interno es: " ,x )
print("El promedio del diámetro externo es: " ,y )
print("El promedio del diámetro medio es: " ,z )
# Out:
# En el laboratorio recolectamos 3 medidas para el diametro interno y el diametro externo
#  con este programa hallaremos el promedio de los dos y el diametro medio.
# Por favor ingrese el primer valor el diametro interno0.0435
# Por favor ingrese el segundo valor el diametro interno0.046
# Por favor ingrese el tercer valor el diametro interno0.044
# Ahora, por favor ingrese el primer valor el diametro externo0.058
# Por favor ingrese el segundo valor el diametro externo0.056
# Por favor ingrese el tercer valor el diametro externo0.0589
# El promedio del diametro interno es:  0.044500000000000005

# %% [markdown]
# Nuestros datos recolectados los ingresamos en una tabla, junto con los de nuestros compañeros
#
# ![Imagen5.png](data:image/png;base64,...)

# %% [markdown]
# 2.  Con la ayuda de Excel, elabore una gráfica de Periodo T(s) Vs D. Medio. Obtenga el modelo
# matemático que representa la función obtenida, y el factor de correlación R 2 , recuerde
# que sus datos tienen un mejor ajuste a la curva de tendencia seleccionada, cuanto este
# factor tiene el valor más próximo a 1. Sobre el modelo matemático obtenido, modifique el
# nombre de las variables (x, y), de acuerdo con el parámetro físico que representan.
#
# ![Imagen1.png](data:image/png;base64,...)

# %% [markdown]
# 3.  Compare la ecuación experimental obtenida, con la ecuación teórica para el Periodo de un
# anillo oscilante T = 2π√ D g. Por medio de esta comparación, obtenga la aceleración
# gravitacional experimental g. Halle el porcentaje de error para la gravedad.
#
# ![Imagen2.png](data:image/png;base64,...)

# %% [markdown]
# 4. Con la ayuda de Excel, elabore una gráfica de D. medio (s) Vs M (kg). Obtenga el modelo
# matemático que representa la función obtenida, y el factor de correlación R 2 , recuerde
# que sus datos tienen un mejor ajuste a la curva de tendencia seleccionada, cuanto este
# factor tiene el valor más próximo a 1. Sobre el modelo matemático obtenido, modifique el
# nombre de las variables (x, y), de acuerdo con el parámetro físico que representan.
# Interprete el resultado de acuerdo con el comportamiento de la función obtenida.
#
# ![Imagen3.png](data:image/png;base64,...)

# %% [markdown]
# En la gráfica de diámetro vs masa se puede observar que la relación entre la masa y el diámetro
# son lineales, partiendo de la recta y=mx, es decir a mayor masa mayor diámetro.

# %% [markdown]
# ![Imagen4.png](data:image/png;base64,...)

# %% [markdown]
# En la gráfica de período vs masa la relación entre estos dos no es una lineal, es una logarítmica y
# es donde mejor está el ajuste de la función con un 93.39% de exactitud. Es decir a mayor masa
# mayor período, pero a medida que aumenta la masa se vuelve constante

# %% [markdown]
# ##CONCLUSIONES
# El periodo es independiente a la masa del péndulo. El periodo es dependiente de la longitud de la
# cuerda del péndulo.
# El método gráfico y estadístico son complementarios ya que con el método gráfico podemos
# observar que forma tiende a tomar la curva ( relación lineal, potencial, exponencial, logarítmica o
# polinómica) con eso podemos saber que ecuación empírica tomar, luego el método estadístico
# nos permite hallar el intercepto y la pendiente y otros datos que se obtienen mediante tablas y
# fórmulas, para al final utilizar toda esta información que se obtuvo y personalizar la ecuación
# empírica al fenómeno y caso que se está experimentando en específico.
# El método de más confiabilidad respecto a las gráficas y la tabulación de los datos es el método
# estadístico ya que usando este método podemos linealizar la curva lo que minimiza el margen de
# error que puede haber en el experimento.

# %% [markdown]
# ##REFERENCIAS
# Cervera, D. R. (s.f.). Métodos y técnicas de investigación. Obtenido de
# https://www.ucm.es/data/cont/media/www/pag-55163/2Metodos.pdf
# Las ecuaciones empíricas. (s.f.). Obtenido de https://www.clubensayos.com/Ciencia/Lasecuaciones-emp%C3%ADricas/745057.htm
